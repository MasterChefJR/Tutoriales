# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterChefJR/Tutoriales/blob/main/Visualizacion_De_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Utilizaremos seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# sns.get_dataset_names()
pinguinos = sns.load_dataset("penguins")
pinguinos.columns = ["especie", "isla", "longitud_pico", "profundidad_pico",
                     "longitud_aleta", "masa", "sexo"]
pinguinos
# Out:
#     especie       isla  longitud_pico  profundidad_pico  longitud_aleta  \
# 0    Adelie  Torgersen           39.1              18.7           181.0
# 1    Adelie  Torgersen           39.5              17.4           186.0
# 2    Adelie  Torgersen           40.3              18.0           195.0
# 3    Adelie  Torgersen            NaN               NaN             NaN
# 4    Adelie  Torgersen           36.7              19.3           193.0
# ..      ...        ...            ...               ...             ...
# 339  Gentoo     Biscoe            NaN               NaN             NaN
# 340  Gentoo     Biscoe           46.8              14.3           215.0
# 341  Gentoo     Biscoe           50.4              15.7           222.0
# 342  Gentoo     Biscoe           45.2              14.8           212.0
# 343  Gentoo     Biscoe           49.9              16.1           213.0
#
#        masa    sexo
# 0    3750.0    Male
# 1    3800.0  Female
# 2    3250.0  Female
# 3       NaN     NaN
# 4    3450.0  Female
# ..      ...     ...
# 339     NaN     NaN
# 340  4850.0  Female
# 341  5750.0    Male
# 342  5200.0  Female
# 343  5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# #Primera grafica de Seaborn
#
# Estilos: White, dark, whitegrid, ticks
#
# contextos: paper, notebook, talk, poster

# %%
sns.set_theme(style="darkgrid", context="talk")
relacional = sns.relplot(data=pinguinos,
                         height=7,
                         aspect=1,
                         markers=["s", ".", "p", "d"])
relacional.set(title="Analisis de Pinguinos")
relacional.set_ylabels("Variables")
relacional.set_xlabels("Numero de pingüinos")
plt.grid(False)
plt.show()

# %% [markdown]
# #Diagramas de Dispersion
#
# Grafica para analizar informacion

# %%
x = " "
print(f'{x:>>30}SIMPLE{x:<>30}\n')

sns.relplot(data=pinguinos,
            x="longitud_pico",
            y="longitud_aleta")

print(f'{x:>>30}Matiz y Tamaño Fijo{x:<>20}\n')

sns.relplot(data=pinguinos,
            x="longitud_pico",
            y="longitud_aleta",
            hue="masa",
            s=300)


print(f'{x:>>30}Rejilla, Tamaño y Personalizado y Estilo{x:<>10}')
sns.relplot(data=pinguinos,
            x="longitud_pico",
            y="longitud_aleta",
            hue="especie",
            row="sexo",
            sizes=(100, 500),
            style="sexo")

sns.relplot(data=pinguinos,
            x="longitud_pico",
            y="longitud_aleta",
            hue="especie",
            col="isla",
            row="sexo",
            sizes=(100, 500),
            style="sexo")
plt.show()
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>> SIMPLE<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Matiz y Tamaño Fijo<<<<<<<<<<<<<<<<<<<
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>> Rejilla, Tamaño y Personalizado y Estilo<<<<<<<<<

# %% [markdown]
# #Gráficos de Línias.

# %%
sns.relplot(data=pinguinos,
            x="especie",
            y="masa",
            kind="line",
            hue="sexo",
            style="sexo",
            ci="sd")
sns.relplot(data=pinguinos,
            x="profundidad_pico",
            y="longitud_aleta",
            kind="line",
            hue="especie",
            style="especie")
plt.show()

# %% [markdown]
# #Combinacion de Graficas
#
# Lineas y Dispersion

# %%
figura, ejes = plt.subplots(1, 2, figsize=(15, 5))
sns.lineplot(data=pinguinos,
            x="especie",
            y="masa",
            hue="sexo",
            style="sexo",
            ci="sd",
            ax=ejes[0])

sns.scatterplot(data=pinguinos,
            x="longitud_pico",
            y="longitud_aleta",
            hue="masa",
            s=300,
            ax=ejes[1])
plt.show()
