# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterChefJR/Tutoriales/blob/main/Visualizaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

eje_x = ["a", "b", "c", "d", "e"]
datos1 = [10, 20, 30, 40, 50]
datos2 = [20, 30, 40, 50, 60]

plt.plot(eje_x, datos1)
plt.show()

plt.plot(eje_x, datos2)
plt.show()

# %% [markdown]
# # Generar Datos a Graficas
#
# ###Examen de Certificacion para Estudiantes de 5 niveles

# %%
import numpy as np

años = ["2011","2012","2013","2014","2015",
        "2016","2017","2018","2019","2020",]

nivel1 = np.random.rand(10)*100
nivel2 = np.random.rand(10)*200 + 100 
nivel3 = np.random.rand(10)*300 + 200 
nivel4 = np.random.rand(10)*400 + 300
nivel5 = np.random.rand(10)*500 + 400

# %% [markdown]
# #Personalizacion de Graficas

# %%
# Introducir series de datos con color, marcador y estilo

plt.plot(años,nivel1, label="Nivel 1", color="blue", marker="<", linestyle="-")
plt.plot(años,nivel2, label="Nivel 2", color="pink", marker="*", linestyle="--")
plt.plot(años,nivel3, label="Nivel 3", color="red", marker="+", linestyle=":")
plt.plot(años,nivel4, label="Nivel 4", color="green", marker=">", linestyle="-.")
plt.plot(años,nivel5, label="Nivel 5", color="black", marker="s", linestyle="solid")

# Activar Leyendas
plt.legend()

# Titulo de Graficas
plt.title("Examen certificacion")

# Etiqueta de los ejes
plt.xlabel("años que se ha realizado el examen")
plt.ylabel("Puntuaje")

# Personalizar eje de puntuaje de 0 a 1000 en iuncremento de 50
plt.yticks(np.arange(0,1001,50))

# Activar cuadricula
plt.grid()

# Activar marcas menores
plt.minorticks_on()

plt.show()

# %% [markdown]
# #Grafica de Barras Verticalez

# %%
eje_x = np.arange(0, 10)

plt.bar(eje_x, nivel5, width=1/5)
plt.bar(eje_x+0.2, nivel4, width=1/5)
plt.bar(eje_x+0.4, nivel3, width=1/5)
plt.bar(eje_x+0.6, nivel2, width=1/5)
plt.bar(eje_x+0.8, nivel1, width=1/5)

plt.show()

# %% [markdown]
# #Grafica de Barras Horizontales (barh)

# %%
eje_x = np.arange(0, 10)

plt.barh(eje_x+0.8, nivel5, height=1/5)
plt.barh(eje_x+0.6, nivel4, height=1/5)
plt.barh(eje_x+0.4, nivel3, height=1/5)
plt.barh(eje_x+0.2, nivel2, height=1/5)
plt.barh(eje_x, nivel1, height=1/5)

plt.show()

# %% [markdown]
# #Grafica de Barras Verticales Apiladas

# %%
plt.bar(eje_x, nivel5)
plt.bar(eje_x, nivel4, bottom=nivel5)
plt.bar(eje_x, nivel3, bottom=nivel4+nivel5)
plt.bar(eje_x, nivel2, bottom=nivel3+nivel4+nivel5)
plt.bar(eje_x, nivel1, bottom=nivel2+nivel3+nivel4+nivel5)

plt.show()

# %% [markdown]
# #Grafica de Dispersion (Scatter)

# %%
plt.scatter(eje_x, nivel5, marker="*")
plt.scatter(eje_x, nivel4)
plt.scatter(eje_x, nivel3)
plt.scatter(eje_x, nivel2)
plt.scatter(eje_x, nivel1)

plt.show()

# %% [markdown]
# #Grafica de Pie

# %%
plt.pie(nivel1, 
        labels=["México","Colombia", "España", "Estados Unidos", "Ecuador",
                "Argentina", "Venezuela", "Puerto Rico", "Honduras", "Uruguay"])

plt.show()

# %% [markdown]
# #Combinar Graficas

# %%
plt.bar(eje_x, nivel1, width=1/5)
plt.bar(eje_x+0.2, nivel1, width=1/5)

plt.plot(años, nivel3)

plt.scatter(eje_x, nivel4)
plt.scatter(eje_x, nivel5)

plt.show()
